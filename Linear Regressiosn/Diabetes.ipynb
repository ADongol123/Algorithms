# %%
from statistics import LinearRegression

import numpy as np 
import pandas as pd
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from LinearRegression import LinerRegression

# %%
data = load_diabetes()
data.data
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.3, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((309, 10), (133, 10), (309,), (133,))

# %%
# Scatter plot of the data points
plt.scatter(X_test[:, 0], y_test, color='blue', label='Actual Data')

# Plot the regression line
plt.plot(X_test[:, 0], y_pred, color='red', label='Regression Line')

# Add labels and legend
plt.title("Linear Regression Scatter Plot")
plt.xlabel("Feature")
plt.ylabel("Target")
plt.legend()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       2 plt.scatter(X_test[:, 0], y_test, color='blue', label='Actual Data')
#       4 # Plot the regression line
# ----> 5 plt.plot(X_test[:, 0], y_pred, color='red', label='Regression Line')
#       7 # Add labels and legend
#       8 plt.title("Linear Regression Scatter Plot")
#
# NameError: name 'y_pred' is not defined

# %%
def MeanSquaredError(y_test, predictions):
    return  np.mean((y_test - predictions) ** 2)

# %%
reg = LinerRegression(lr=0.1, iterations=1000)  # Adjust learning rate and iterations as needed
reg.fit(X_train, y_train)

# %%
predictions = reg.predict(X_test)
y_pred_line = reg.predict(X_train)

# %%
def MeanSquaredError(y_test, predictions):
    return np.mean((y_test - predictions) ** 2)

mse = MeanSquaredError(y_test, predictions)
print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Squared Error (MSE): 3522.3613746804203

# %%
feature_index = 2  # Example: Index for BMI feature in the dataset
plt.scatter(X_test[:, feature_index], y_test, color='blue', label='Actual')
plt.scatter(X_test[:, feature_index], predictions, color='red', label='Predicted')
# plt.plot(X_train[:, feature_index],y_pred_line,color='black',linewidth=2,label='Prediction')
plt.title("Linear Regression - Diabetes Dataset")
plt.xlabel("Feature: BMI")
plt.ylabel("Target: Disease Progression")
plt.legend()
plt.show()
